# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient(
    "mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority"
)
db = client.sample_supplies  # nome del database

# %%
df = db.sales.find_one()
df

# %%
df = pd.DataFrame(list(db.sales.find()))
df

# %%
client2 = pymongo.MongoClient(
    "mongodb://Luca:Luca@cluster0-shard-00-00.dl9eb.mongodb.net:27017,cluster0-shard-00-01.dl9eb.mongodb.net:27017,cluster0-shard-00-02.dl9eb.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-8a6zwm-shard-0&authSource=admin&retryWrites=true&w=majority"
)
db2 = client.sample_vendite  # nome del database

# %%
'''db2.vendite.insert_many(df.to_dict("records"))'''
# Out:
# 'db2.vendite.insert_many(df.to_dict("records"))'

# %%
df = pd.DataFrame(list(db2.vendite.find()))
df
# Out:
#                          _id saleDate  \
# 0   5bd761dcae323e45a93cd0d7     None
# 1   5bd761dcae323e45a93cd2a3     None
# 2   5bd761ddae323e45a93cd6db     None
# 3   5bd761ddae323e45a93cd8dc     None
# 4   5bd761ddae323e45a93cd7db     None
# 5   5bd761ddae323e45a93cda46     None
# 6   5bd761ddae323e45a93cdaac     None
# 7   5bd761ddae323e45a93cda1b     None
# 8   5bd761deae323e45a93cddc0     None
# 9   5bd761deae323e45a93cdf41     None
# 10  5bd761deae323e45a93ce162     None
# 11  5bd761deae323e45a93ce231     None
# 12  5bd761deae323e45a93ce319     None
#
#                                                 items storeLocation  \
# 0   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 1   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 2   [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 3   [{'name': 'backpack', 'tags': ['school', 'trav...        Austin
# 4   [{'name': 'binder', 'tags': ['school', 'genera...        London
# 5   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 6   [{'name': 'backpack', 'tags': ['school', 'trav...        Denver
# 7   [{'name': 'notepad', 'tags': ['office', 'writi...        Austin
# 8   [{'name': 'notepad', 'tags': ['office', 'writi...       Seattle
# 9   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 10  [{'name': 'notepad', 'tags': ['office', 'writi...        London
# 11  [{'name': 'binder', 'tags': ['school', 'genera...      New York
# 12  [{'name': 'laptop', 'tags': ['electronics', 's...       Seattle
#
#                                              customer  couponUsed  \
# 0   {'gender': 'M', 'age': 80, 'email': 'hez@juepi...       False
# 1   {'gender': 'M', 'age': 80, 'email': 'tahketnid...       False
# 2   {'gender': 'M', 'age': 80, 'email': 'ek@ho.ie'...       False
# 3   {'gender': 'F', 'age': 80, 'email': 'tuum@rouj...       False
# 4   {'gender': 'F', 'age': 80, 'email': 'buz@nofi....       False
# 5   {'gender': 'M', 'age': 80, 'email': 'emioheke@...       False
# 6   {'gender': 'F', 'age': 80, 'email': 'neob@umih...       False
# 7   {'gender': 'M', 'age': 80, 'email': 'ibceprov@...       False
# 8   {'gender': 'M', 'age': 80, 'email': 'duv@van.g...       False
# 9   {'gender': 'F', 'age': 80, 'email': 'fim@cep.k...       False
# 10  {'gender': 'M', 'age': 80, 'email': 'ehzina@gi...       False
# 11  {'gender': 'M', 'age': 80, 'email': 'uzhusi@hu...       False
# 12  {'gender': 'M', 'age': 80, 'email': 'gerdol@ke...       False
#
#    purchaseMethod     costumer
# 0        In store  {'age': 24}
# 1        In store  {'age': 24}
# 2        In store  {'age': 24}
# 3        In store  {'age': 24}
# 4           Phone  {'age': 24}
# 5          Online  {'age': 24}
# 6        In store  {'age': 24}
# 7           Phone  {'age': 24}
# 8        In store  {'age': 24}
# 9          Online  {'age': 24}
# 10       In store  {'age': 24}
# 11       In store  {'age': 24}
# 12          Phone  {'age': 24}

# %%
# 1. cancellare tutti i document relativi al negozio di San Diego

result = db2.vendite.delete_many({"storeLocation" : "San Dieg"})
result.deleted_count
# Out:
# 0

# %%
# 2. invecchiare i clienti di 8 anni

result = db2.vendite.update_many({},{"$inc" : {"customer.age" : 8}})
result.modified_count
df
# Out:
#                          _id saleDate  \
# 0   5bd761dcae323e45a93cd0d7     None
# 1   5bd761dcae323e45a93cd2a3     None
# 2   5bd761ddae323e45a93cd6db     None
# 3   5bd761ddae323e45a93cd8dc     None
# 4   5bd761ddae323e45a93cd7db     None
# 5   5bd761ddae323e45a93cda46     None
# 6   5bd761ddae323e45a93cdaac     None
# 7   5bd761ddae323e45a93cda1b     None
# 8   5bd761deae323e45a93cddc0     None
# 9   5bd761deae323e45a93cdf41     None
# 10  5bd761deae323e45a93ce162     None
# 11  5bd761deae323e45a93ce231     None
# 12  5bd761deae323e45a93ce319     None
#
#                                                 items storeLocation  \
# 0   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 1   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 2   [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 3   [{'name': 'backpack', 'tags': ['school', 'trav...        Austin
# 4   [{'name': 'binder', 'tags': ['school', 'genera...        London
# 5   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 6   [{'name': 'backpack', 'tags': ['school', 'trav...        Denver
# 7   [{'name': 'notepad', 'tags': ['office', 'writi...        Austin
# 8   [{'name': 'notepad', 'tags': ['office', 'writi...       Seattle
# 9   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 10  [{'name': 'notepad', 'tags': ['office', 'writi...        London
# 11  [{'name': 'binder', 'tags': ['school', 'genera...      New York
# 12  [{'name': 'laptop', 'tags': ['electronics', 's...       Seattle
#
#                                              customer  couponUsed  \
# 0   {'gender': 'M', 'age': 80, 'email': 'hez@juepi...       False
# 1   {'gender': 'M', 'age': 80, 'email': 'tahketnid...       False
# 2   {'gender': 'M', 'age': 80, 'email': 'ek@ho.ie'...       False
# 3   {'gender': 'F', 'age': 80, 'email': 'tuum@rouj...       False
# 4   {'gender': 'F', 'age': 80, 'email': 'buz@nofi....       False
# 5   {'gender': 'M', 'age': 80, 'email': 'emioheke@...       False
# 6   {'gender': 'F', 'age': 80, 'email': 'neob@umih...       False
# 7   {'gender': 'M', 'age': 80, 'email': 'ibceprov@...       False
# 8   {'gender': 'M', 'age': 80, 'email': 'duv@van.g...       False
# 9   {'gender': 'F', 'age': 80, 'email': 'fim@cep.k...       False
# 10  {'gender': 'M', 'age': 80, 'email': 'ehzina@gi...       False
# 11  {'gender': 'M', 'age': 80, 'email': 'uzhusi@hu...       False
# 12  {'gender': 'M', 'age': 80, 'email': 'gerdol@ke...       False
#
#    purchaseMethod     costumer
# 0        In store  {'age': 24}
# 1        In store  {'age': 24}
# 2        In store  {'age': 24}
# 3        In store  {'age': 24}
# 4           Phone  {'age': 24}
# 5          Online  {'age': 24}
# 6        In store  {'age': 24}
# 7           Phone  {'age': 24}
# 8        In store  {'age': 24}
# 9          Online  {'age': 24}
# 10       In store  {'age': 24}
# 11       In store  {'age': 24}
# 12          Phone  {'age': 24}

# %%
# 3. cancellare tutti i tag 'stationary'

result = db2.vendite.update_many({},{"$pull" : {"items": {"tags": "stationary"}}})
result.modified_count
# Out:
# 0

# %%
df = pd.DataFrame(list(db2.vendite.find()))
df
# Out:
#                          _id saleDate  \
# 0   5bd761dcae323e45a93cd0d7     None
# 1   5bd761dcae323e45a93cd2a3     None
# 2   5bd761ddae323e45a93cd6db     None
# 3   5bd761ddae323e45a93cd8dc     None
# 4   5bd761ddae323e45a93cd7db     None
# 5   5bd761ddae323e45a93cda46     None
# 6   5bd761ddae323e45a93cdaac     None
# 7   5bd761ddae323e45a93cda1b     None
# 8   5bd761deae323e45a93cddc0     None
# 9   5bd761deae323e45a93cdf41     None
# 10  5bd761deae323e45a93ce162     None
# 11  5bd761deae323e45a93ce231     None
# 12  5bd761deae323e45a93ce319     None
#
#                                                 items storeLocation  \
# 0   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 1   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 2   [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 3   [{'name': 'backpack', 'tags': ['school', 'trav...        Austin
# 4   [{'name': 'binder', 'tags': ['school', 'genera...        London
# 5   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 6   [{'name': 'backpack', 'tags': ['school', 'trav...        Denver
# 7   [{'name': 'notepad', 'tags': ['office', 'writi...        Austin
# 8   [{'name': 'notepad', 'tags': ['office', 'writi...       Seattle
# 9   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 10  [{'name': 'notepad', 'tags': ['office', 'writi...        London
# 11  [{'name': 'binder', 'tags': ['school', 'genera...      New York
# 12  [{'name': 'laptop', 'tags': ['electronics', 's...       Seattle
#
#                                              customer  couponUsed  \
# 0   {'gender': 'M', 'age': 88, 'email': 'hez@juepi...       False
# 1   {'gender': 'M', 'age': 88, 'email': 'tahketnid...       False
# 2   {'gender': 'M', 'age': 88, 'email': 'ek@ho.ie'...       False
# 3   {'gender': 'F', 'age': 88, 'email': 'tuum@rouj...       False
# 4   {'gender': 'F', 'age': 88, 'email': 'buz@nofi....       False
# 5   {'gender': 'M', 'age': 88, 'email': 'emioheke@...       False
# 6   {'gender': 'F', 'age': 88, 'email': 'neob@umih...       False
# 7   {'gender': 'M', 'age': 88, 'email': 'ibceprov@...       False
# 8   {'gender': 'M', 'age': 88, 'email': 'duv@van.g...       False
# 9   {'gender': 'F', 'age': 88, 'email': 'fim@cep.k...       False
# 10  {'gender': 'M', 'age': 88, 'email': 'ehzina@gi...       False
# 11  {'gender': 'M', 'age': 88, 'email': 'uzhusi@hu...       False
# 12  {'gender': 'M', 'age': 88, 'email': 'gerdol@ke...       False
#
#    purchaseMethod     costumer
# 0        In store  {'age': 24}
# 1        In store  {'age': 24}
# 2        In store  {'age': 24}
# 3        In store  {'age': 24}
# 4           Phone  {'age': 24}
# 5          Online  {'age': 24}
# 6        In store  {'age': 24}
# 7           Phone  {'age': 24}
# 8        In store  {'age': 24}
# 9          Online  {'age': 24}
# 10       In store  {'age': 24}
# 11       In store  {'age': 24}
# 12          Phone  {'age': 24}

# %%
# 4. eliminare tutti i document di clienti che hanno più di 80 anni e meno di 40

result = db2.vendite.delete_many({"$or" : [{"customer.age" : {"$gt" : 80}},{"customer.age" : {"$lt" : 40}}]})
result.deleted_count
# Out:
# 13

# %%
# 5. calcolare il prezzo medio degli items

result = db2.vendite.aggregate([{"$unwind": "$items"},
                              {"$group": {"_id": "prezzo medio", "prezzoMedio": {"$avg":"$items.price"}}},
                              { "$project": { "prezzoMedio": { "$round": [ "$prezzoMedio", 2 ] } } }
])

df = pd.DataFrame(list(result))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 6. modificare le mail che hanno il dominio .mz in .com
result = db2.vendite.update_many({"customer.email" : {"$regex" : ".mz\\b"}}, 
                                 [{"$set" : {"customer.email" : {"$replaceOne" : {"input" : "$email", "find" : ".mz", "replacement" : ".com"}}}}])
result.modified_count
# Out:
# 0

# %%
# 7. modificare il tag 'school' in 'education"
result = db2.vendite.update_many({"items.name" : {"$regex" : "school"}}, 
                                 [{"$set" : {"items.tags" : {"$replaceOne" : {"input" : "$tags", "find" : "school", "replacement" : "education"}}}}]
                                 )
result.modified_count
df
# Out:
#                          _id saleDate  \
# 0   5bd761dcae323e45a93cd0d7     None
# 1   5bd761dcae323e45a93cd2a3     None
# 2   5bd761ddae323e45a93cd6db     None
# 3   5bd761ddae323e45a93cd8dc     None
# 4   5bd761ddae323e45a93cd7db     None
# 5   5bd761ddae323e45a93cda46     None
# 6   5bd761ddae323e45a93cdaac     None
# 7   5bd761ddae323e45a93cda1b     None
# 8   5bd761deae323e45a93cddc0     None
# 9   5bd761deae323e45a93cdf41     None
# 10  5bd761deae323e45a93ce162     None
# 11  5bd761deae323e45a93ce231     None
# 12  5bd761deae323e45a93ce319     None
#
#                                                 items storeLocation  \
# 0   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 1   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 2   [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 3   [{'name': 'backpack', 'tags': ['school', 'trav...        Austin
# 4   [{'name': 'binder', 'tags': ['school', 'genera...        London
# 5   [{'name': 'notepad', 'tags': ['office', 'writi...      New York
# 6   [{'name': 'backpack', 'tags': ['school', 'trav...        Denver
# 7   [{'name': 'notepad', 'tags': ['office', 'writi...        Austin
# 8   [{'name': 'notepad', 'tags': ['office', 'writi...       Seattle
# 9   [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 10  [{'name': 'notepad', 'tags': ['office', 'writi...        London
# 11  [{'name': 'binder', 'tags': ['school', 'genera...      New York
# 12  [{'name': 'laptop', 'tags': ['electronics', 's...       Seattle
#
#                                              customer  couponUsed  \
# 0   {'gender': 'M', 'age': 88, 'email': 'hez@juepi...       False
# 1   {'gender': 'M', 'age': 88, 'email': 'tahketnid...       False
# 2   {'gender': 'M', 'age': 88, 'email': 'ek@ho.ie'...       False
# 3   {'gender': 'F', 'age': 88, 'email': 'tuum@rouj...       False
# 4   {'gender': 'F', 'age': 88, 'email': 'buz@nofi....       False
# 5   {'gender': 'M', 'age': 88, 'email': 'emioheke@...       False
# 6   {'gender': 'F', 'age': 88, 'email': 'neob@umih...       False
# 7   {'gender': 'M', 'age': 88, 'email': 'ibceprov@...       False
# 8   {'gender': 'M', 'age': 88, 'email': 'duv@van.g...       False
# 9   {'gender': 'F', 'age': 88, 'email': 'fim@cep.k...       False
# 10  {'gender': 'M', 'age': 88, 'email': 'ehzina@gi...       False
# 11  {'gender': 'M', 'age': 88, 'email': 'uzhusi@hu...       False
# 12  {'gender': 'M', 'age': 88, 'email': 'gerdol@ke...       False
#
#    purchaseMethod     costumer
# 0        In store  {'age': 24}
# 1        In store  {'age': 24}
# 2        In store  {'age': 24}
# 3        In store  {'age': 24}
# 4           Phone  {'age': 24}
# 5          Online  {'age': 24}
# 6        In store  {'age': 24}
# 7           Phone  {'age': 24}
# 8        In store  {'age': 24}
# 9          Online  {'age': 24}
# 10       In store  {'age': 24}
# 11       In store  {'age': 24}
# 12          Phone  {'age': 24}

# %%
# 8. aggiungere 7 anni alla data degli ordini
result = db2.vendite.update_many(
  { "saleDate" : { "$exists" : "true" }},
  [{ "$set": { "saleDate": { "$dateAdd": { "startDate": "$saleDate", "unit": "year", "amount": 7}}}}]
)
result.modified_count
# Out:
# 0

# %%
# 9. trovare il prodotto venduto più costoso

result = db2.vendite.aggregate([
     {
    '$unwind': '$items',
    
  },                             

    { "$group": {
        "_id": "maxPrice ",
        "maxPrice": {
            "$max": "$items.price"
        },
        "customerdata": {
            "$push": {
                
                "email": "$customer.email",       
            }
        }
       }
    },
{
    
    '$unwind': '$maxPrice',
}


    ])
df = pd.DataFrame(list(result))
df

# %%
# 10. eliminare dagli ordini tutti i prodotti "envelopes"
result = db2.vendite.delete_many({"items.name":'envelopes'})
result.deleted_count
# Out:
# 0

# %%
# 11. copiare la collection "vendite" nella collection "vendite_modificata"
db2.vendite.aggregate([{"$out": "mycopy"}])

# %%
df1 = pd.DataFrame(list(db2.mycopy.find()))
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 12. eliminare la collection "vendite"
'''result = db2.Vendite.drop()'''
# Out:
# 'result = db2.Vendite.drop()'
